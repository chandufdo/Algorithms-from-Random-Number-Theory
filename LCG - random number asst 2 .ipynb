# %%
## using a list method for LCG generator 

import matplotlib.pyplot as plt 


n = 1000 
m = 2147483647
a = 16807
x = 0.5
c = 0
i = 1
X = [x]
u = x/m
U = [u]

for i in range(0,n-1):
    x = (a*x + c)%m
    u = x/m
    i = i+1
    U.append(u)

x1 = list(range(0,n))
plt.figure()
plt.hist(U)
plt.show()

plt.figure()
plt.plot(x1,U,'.b')
plt.title("Generated random numbers")
plt.xlabel("Index no.")
plt.ylabel("Random no.")
# Out:
# Text(0, 0.5, 'Random no.')

# %%
import numpy as np

import matplotlib.pyplot as plt


n = 100
x = np.zeros(n)
x[0] = 1000
a = 16807
c = 0
m = 2147483647
U = np.zeros(n)

for i in range(0, n - 1):
    x[i + 1] = ((a * x[i]) + c) % m

for i in range(n):
    U[i] = x[i] / m

# print(x)
print(U)

plt.figure()
X=np.linspace(0,100,100)
Y=U
plt.plot(X,U,".b")
#plt.hist(U)
plt.show()

# %%
# Out:
# Text(0, 0.5, 'Random no.')
